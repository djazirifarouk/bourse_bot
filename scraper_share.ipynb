# %% [markdown]
# Loading Quotes

# %%
import pandas as pd

# Load only the Company_Name and Quote_Code of the latest Publication_Date
quotes_df = pd.read_csv('quotes_potential.csv', usecols=['Company_Name', 'Quote_Code', 'Publication_Date'])
quotes_df['Publication_Date'] = pd.to_datetime(quotes_df['Publication_Date'])
latest_date = quotes_df['Publication_Date'].max()
latest_quotes_df = quotes_df[quotes_df['Publication_Date'] == latest_date][['Quote_Code', 'Company_Name']]
print(f"✅ Loaded {len(latest_quotes_df)} quotes from the latest published date: {latest_date.strftime('%Y-%m-%d')}")
# Out:
# ✅ Loaded 86 quotes from the latest published date: 2026-02-07

# %%
import requests
from bs4 import BeautifulSoup

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
}

# %% [markdown]
# shares

# %%
shares = pd.DataFrame([])
for quote in latest_quotes_df['Quote_Code']:
    url = f'https://www.ilboursa.com/marches/societe/{quote}'
    response = requests.get(url, headers=headers, timeout=30)
    soup = BeautifulSoup(response.content, 'html.parser')
    lst_actionnaires = soup.find('span', {'id': 'lstActionnaires'})

    if lst_actionnaires:
        raw_data = lst_actionnaires.text.strip()
        shareholders = []
        for entry in raw_data.split(';'):
            if '*' in entry:
                name, percentage = entry.split('*')
                percentage = percentage.replace(',', '.').strip()  # Remove % and whitespace
                shareholders.append({
                    'Shareholder': name.strip().upper(),
                    'Percentage': float(percentage)
                })
        
        df = pd.DataFrame(shareholders)
        df['Quote_Code'] = quote
        shares = pd.concat([shares, df], ignore_index=True)
        print(f"\n✅ Found {len(df)} shareholders:")
        print(df)
    else:
        print("❌ No shareholder data found")
    
shares["Publication_Date"] = pd.to_datetime('today').strftime('%Y-%m-%d')
# Loading existing shares.csv if it exists
try:
    existing_shares = pd.read_csv('shares.csv')
    shares = pd.concat([existing_shares, shares], ignore_index=True)
    shares.drop_duplicates(keep='last', inplace=True)
except FileNotFoundError:
    pass
# Saving to shares.csv
shares.to_csv('shares.csv', index=False)
# Out:
# ✅ Found 1 shareholders:
#      Shareholder  Percentage Quote_Code
# 0  GROUPE KILANI       99.16      ADWYA
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                ZOUBEIR CHAIEB       67.77      AETEC
# 1  PUBLIC SUR LA PLACE DE TUNIS       32.23      AETEC
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0     AIR LIQUIDE INTERNATIONAL       59.11         AL
# 1             BANQUE DE TUNISIE       16.46         AL
# 2  PUBLIC SUR LA PLACE DE TUNIS       13.37         AL
# 3                    GROUPE BNA       11.06         AL
#
# ✅ Found 4 shareholders:
#              Shareholder  Percentage Quote_Code
# 0        ASSURANCE COMAR       30.80         AB
# 1            PGI HOLDING       20.85         AB
# 2  STE ENNAKL AUTOMOBILE        7.93         AB
# 3         EKUITY CAPITAL        5.00         AB
#
# ✅ Found 0 shareholders:
# Empty DataFrame
# Columns: [Quote_Code]
# Index: []
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                 ARAB BANK PLC       64.24        ATB
# 1  PUBLIC SUR LA PLACE DE TUNIS       30.44        ATB
# 2                GROUPE ZERZERI        5.32        ATB
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS        40.7        ATL
# 1            ARAB TUNISIAN BANK        40.0        ATL
# 2                    GROUPE BNA        11.1        ATL
# 3         STE ENNAKL AUTOMOBILE         8.2        ATL
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0           MOHAMED SADOK MZABI       27.45      ARTES
# 1                  MONCEF MZABI       26.29      ARTES
# 2                 MZOUGHI MZABI       22.99      ARTES
# 3  PUBLIC SUR LA PLACE DE TUNIS       13.93      ARTES
# 4                ABU DHABI FUND        9.32      ARTES
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       59.95      ASSAD
# 1             ABDELWAHEB KALLEL       11.81      ASSAD
# 2                 SAMIBEN AHMED       11.66      ASSAD
# 3                SOUHEIL KALLEL       10.63      ASSAD
# 4                   FIRAS BECHA        5.95      ASSAD
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0              UNION FINANCIERE        56.9      ASSMA
# 1  PUBLIC SUR LA PLACE DE TUNIS        43.1      ASSMA
#
# ✅ Found 4 shareholders:
#                               Shareholder  Percentage Quote_Code
# 0                       BANQUE DE TUNISIE       50.32        AST
# 1  GROUPE DES ASSURANCES DU CRÉDIT MUTUEL       30.00        AST
# 2            PUBLIC SUR LA PLACE DE TUNIS       11.83        AST
# 3                PLACEMENTS TUNISIE SICAF        7.85        AST
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0        ANDALUCARTHAGE HOLDING       57.21      TJARI
# 1  PUBLIC SUR LA PLACE DE TUNIS       23.32      TJARI
# 2                  GROUPE MZABI       10.00      TJARI
# 3                  GROUPE DRISS        9.47      TJARI
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0               GROUPE ATTIJARI       63.78        TJL
# 1  PUBLIC SUR LA PLACE DE TUNIS       14.99        TJL
# 2               GROUPE HORCHANI        9.09        TJL
# 3                GROUPE KAMMOUN        6.26        TJL
# 4                GROUPE SELLAMI        5.80        TJL
#
# ✅ Found 4 shareholders:
#                           Shareholder  Percentage Quote_Code
# 0        PUBLIC SUR LA PLACE DE TUNIS       45.56         BT
# 1  BANQUE FÉDÉRATIVE DU CRÉDIT MUTUEL       35.33         BT
# 2          GROUPE ABDELLATIF EL FEKIH       10.00         BT
# 3                GROUPE HABIB KAMMOUN        9.11         BT
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       64.74        BNA
# 1                 ÉTAT TUNISIEN       35.26        BNA
#
# ✅ Found 4 shareholders:
#                           Shareholder  Percentage Quote_Code
# 0  ARAB LEASING INTERNATIONAL FINANCE       40.68         BL
# 1                      AL BARAKA BANK       23.60         BL
# 2        PUBLIC SUR LA PLACE DE TUNIS       22.99         BL
# 3                       ISSA HIDOUSSI       12.73         BL
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                GROUPE BH BANK       39.24      BHASS
# 1         POULINA GROUP HOLDING       37.61      BHASS
# 2  PUBLIC SUR LA PLACE DE TUNIS       11.93      BHASS
# 3                AHMED TRABELSI        5.72      BHASS
# 4                 HAIFA LAARIBI        5.50      BHASS
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                 ÉTAT TUNISIEN       33.37         BH
# 1  PUBLIC SUR LA PLACE DE TUNIS       27.26         BH
# 2               GROUPE HORCHANI       22.41         BH
# 3                          ETAP       16.57         BH
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                GROUPE BH BANK       41.64        BHL
# 1  PUBLIC SUR LA PLACE DE TUNIS       30.89        BHL
# 2                 BH ASSURANCES       10.00        BHL
# 3          EPARGNE INVEST SICAF        9.77        BHL
# 4                     BH EQUITY        7.70        BHL
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                GROUPE MABROUK       38.75       BIAT
# 1  PUBLIC SUR LA PLACE DE TUNIS       29.11       BIAT
# 2             GROUPE AZIZ MILAD       15.01       BIAT
# 3             GROUPE TAMARZISTE        9.30       BIAT
# 4               GROUPE HORCHANI        7.83       BIAT
#
# ✅ Found 2 shareholders:
#       Shareholder  Percentage Quote_Code
# 0  ABU DHABI FUND        50.0        BTE
# 1   ÉTAT TUNISIEN        50.0        BTE
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                BINA CORPORATE       40.20         CC
# 1  PUBLIC SUR LA PLACE DE TUNIS       39.98         CC
# 2             AL KARAMA HOLDING       14.85         CC
# 3               SOCIÉTÉ EL HANA        4.97         CC
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       34.38       CELL
# 1                 Y.K.H HOLDING       31.87       CELL
# 2                YASSINE HAMILA       11.25       CELL
# 3                   ALYA HAMILA       11.25       CELL
# 4                    EYA HAMILA       11.25       CELL
#
# ✅ Found 0 shareholders:
# Empty DataFrame
# Columns: [Quote_Code]
# Index: []
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0       STÉ GÉNÉRALE FINANCIÈRE       40.48        CIL
# 1  PUBLIC SUR LA PLACE DE TUNIS       38.96        CIL
# 2       TUNISIAN TRAVEL SERVICE       11.57        CIL
# 3                TTS FINANCIERE        8.99        CIL
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                 ÉTAT TUNISIEN       79.92        SCB
# 1  PUBLIC SUR LA PLACE DE TUNIS       20.08        SCB
#
# ✅ Found 2 shareholders:
#                         Shareholder  Percentage Quote_Code
# 0  CONSORTIUM BOUCHAMAOUI-CHABCHOUB        66.5       CITY
# 1      PUBLIC SUR LA PLACE DE TUNIS        33.5       CITY
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                FAMILLE MEDDEB       85.00         DH
# 1  PUBLIC SUR LA PLACE DE TUNIS        8.93         DH
# 2       STE AGRICOLE EL HADAYEK        6.07         DH
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0   STE FETHI HACHICHA SERVICES       71.70       LSTR
# 1  PUBLIC SUR LA PLACE DE TUNIS       12.30       LSTR
# 2        FINANCIERE WIDED SICAF        9.18       LSTR
# 3                FETHI HACHICHA        6.82       LSTR
#
# ✅ Found 4 shareholders:
#                          Shareholder  Percentage Quote_Code
# 0                     PGI-AMEN GROUP       54.17       NAKL
# 1              POULINA GROUP HOLDING       28.70       NAKL
# 2  PUBLIC SUR LA PLACE DE CASABLANCA       10.00       NAKL
# 3       PUBLIC SUR LA PLACE DE TUNIS        7.13       NAKL
#
# ✅ Found 0 shareholders:
# Empty DataFrame
# Columns: [Quote_Code]
# Index: []
#
# ✅ Found 6 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       35.66      ECYCL
# 1                 HABIB ESSAYEH       33.36      ECYCL
# 2                 MOHAMED REKIK       10.59      ECYCL
# 3                  MOURAD GHAZY        7.86      ECYCL
# 4                MICHEL BERAUDO        6.99      ECYCL
# 5                     MG INVEST        5.54      ECYCL
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       33.96        GIF
# 1                 ECONOMIC AUTO       33.91        GIF
# 2                    AURES AUTO       13.14        GIF
# 3                 BASSEM LOUKIL        9.62        GIF
# 4                  WALID LOUKIL        9.35        GIF
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                GROUPE DJILANI       41.49         HL
# 1  PUBLIC SUR LA PLACE DE TUNIS       34.03         HL
# 2                  GROUPE KIPCO       11.16         HL
# 3                         CTAMA        7.86         HL
# 4                           MAE        5.46         HL
#
# ✅ Found 1 shareholders:
#   Shareholder  Percentage Quote_Code
# 0   GROUPE 3S       100.0      XABYT
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       37.63        ICF
# 1                        ARMICO       26.67        ICF
# 2     STE MARHABA INTERNATIONAL       18.89        ICF
# 3             STE MARHABA BEACH       17.22        ICF
#
# ✅ Found 3 shareholders:
#                            Shareholder  Percentage Quote_Code
# 0                      LAND’OR HOLDING       47.64      LNDOR
# 1  MAGHREB PRIVATE EQUITY FUND III PCC       36.17      LNDOR
# 2         PUBLIC SUR LA PLACE DE TUNIS       16.19      LNDOR
#
# ✅ Found 3 shareholders:
#                             Shareholder  Percentage Quote_Code
# 0  MED INVEST COMPANY ( GROUPE BAYAHI )       76.69        MAG
# 1          PUBLIC SUR LA PLACE DE TUNIS       16.03        MAG
# 2                          STE NEW CORP        7.28        MAG
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0           ASSURANCE MAGHREBIA       58.74        AMV
# 1  PUBLIC SUR LA PLACE DE TUNIS       32.91        AMV
# 2              UNION FINANCIERE        8.35        AMV
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0           FAMILLE BEN SLIMANE       58.66        SAM
# 1  PUBLIC SUR LA PLACE DE TUNIS       41.34        SAM
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                 GROUPE LAWHAT        85.0        MIP
# 1  PUBLIC SUR LA PLACE DE TUNIS        15.0        MIP
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                GROUPE MABROUK       64.94        MNP
# 1  PUBLIC SUR LA PLACE DE TUNIS       23.27        MNP
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0               SOFIANE SELLAMI       56.13       MPBS
# 1  PUBLIC SUR LA PLACE DE TUNIS       37.38       MPBS
# 2                KHALED SELLAMI        6.67       MPBS
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0              KARIM REJEB SFAR       52.40        NBL
# 1  PUBLIC SUR LA PLACE DE TUNIS       36.66        NBL
# 2                  NESSIM REJEB       10.94        NBL
#
# ✅ Found 6 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       31.11      PLAST
# 1                     ATD SICAR       28.29      PLAST
# 2                  YASSINE ABID       20.71      PLAST
# 3               FCPR MAX-JASMIN        9.40      PLAST
# 4                AMI ASSURANCES        5.25      PLAST
# 5               FCPR MAX ESPOIR        5.24      PLAST
#
# ✅ Found 7 shareholders:
#                            Shareholder  Percentage Quote_Code
# 0         PUBLIC SUR LA PLACE DE TUNIS       33.81        OTH
# 1                       MONCEF SELLAMI       26.20        OTH
# 2                         SLIM SELLAMI       10.44        OTH
# 3                          AFRICINVEST        8.79        OTH
# 4  MAGHREB PRIVATE EQUITY FUND III PCC        8.20        OTH
# 5                         HÉDI SELLAMI        7.12        OTH
# 6                       EKUITY CAPITAL        5.44        OTH
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0     FOUNDERS CAPITAL PARTNERS       74.39        PGH
# 1  PUBLIC SUR LA PLACE DE TUNIS       19.92        PGH
# 2               SOCIÉTÉ EL HANA        5.69        PGH
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                    JM HOLDING       64.67        SAH
# 1  PUBLIC SUR LA PLACE DE TUNIS       22.48        SAH
# 2                EKUITY CAPITAL        7.32        SAH
# 3                           ECP        5.53        SAH
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0        SOCIÉTÉ AB-CORPORATION       50.31        SMD
# 1  PUBLIC SUR LA PLACE DE TUNIS       24.34        SMD
# 2                     ATD SICAR       13.64        SMD
# 3             LOTFI ABDENNADHER       11.71        SMD
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       48.87      SERVI
# 1              SERVICOM HOLDING       29.80      SERVI
# 2                   AFRICINVEST       11.23      SERVI
# 3    FCPR DÉVELOPEMENT RÉGIONAL       10.10      SERVI
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                 GROUPE CASTEL       63.03       SFBT
# 1  PUBLIC SUR LA PLACE DE TUNIS       21.83       SFBT
# 2            PARTNER INVESTMENT       10.14       SFBT
# 3                          STAR        5.00       SFBT
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       56.60      SIAME
# 1         MOHAMED HEDI BEN AYED       20.70      SIAME
# 2                       COTUNAL        8.21      SIAME
# 3                    INTERMETAL        8.12      SIAME
# 4                        PROSID        6.41      SIAME
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                    GROUPE BNA       30.27      SIMPA
# 1  PUBLIC SUR LA PLACE DE TUNIS       27.37      SIMPA
# 2                           GAT       26.71      SIMPA
# 3                         CTAMA       10.58      SIMPA
# 4                  SOIVIM SICAF        5.07      SIMPA
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0            PHARMACIE CENTRALE       67.78      SIPHA
# 1  PUBLIC SUR LA PLACE DE TUNIS       20.01      SIPHA
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0            PARTNER INVESTMENT       75.95       SITS
# 1  PUBLIC SUR LA PLACE DE TUNIS        8.96       SITS
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                FAMILLE ESSAFI        35.5      SMART
# 1                FAMILLE BOUDEN        23.4      SMART
# 2  PUBLIC SUR LA PLACE DE TUNIS        17.2      SMART
# 3            TAOUFIK BEN KHEMIS        15.1      SMART
# 4                         MYTEK         8.7      SMART
#
# ✅ Found 6 shareholders:
#                              Shareholder  Percentage Quote_Code
# 0               GROUPE CHIMIQUE TUNISIEN       39.10      ALKIM
# 1                           SOCIÉTÉ IMER       22.12      ALKIM
# 2           PUBLIC SUR LA PLACE DE TUNIS       20.82      ALKIM
# 3                           GROUPE CARTE       10.48      ALKIM
# 4  SOCIÉTÉ HÔTELIÈRE EL KANTAOUI MARHABA        7.48      ALKIM
# 5                                   STEC        7.38      ALKIM
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       66.90      SOMOC
# 1               SOCIÉTÉ AGRIMED       16.79      SOMOC
# 2        SOCIÉTÉ AB-CORPORATION       11.13      SOMOC
# 3             LOTFI ABDENNADHER        5.39      SOMOC
#
# ✅ Found 5 shareholders:
#                      Shareholder  Percentage Quote_Code
# 0                 GALLUS HOLDING       41.34      SOPAT
# 1   PUBLIC SUR LA PLACE DE TUNIS       24.93      SOPAT
# 2                      MEDIGRAIN       17.73      SOPAT
# 3  LES GRANDS MOULINS DU CAP BON       10.93      SOPAT
# 4                           MCSR        5.07      SOPAT
#
# ✅ Found 4 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                       SOMOCER       63.27      SOTEM
# 1                     ATD SICAR       26.68      SOTEM
# 2                ATTIJARI SICAR        5.61      SOTEM
# 3  PUBLIC SUR LA PLACE DE TUNIS        4.44      SOTEM
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS        65.0      SOTET
# 1               TUNISIE TELECOM        35.0      SOTET
#
# ✅ Found 5 shareholders:
#                          Shareholder  Percentage Quote_Code
# 0                     RECALL HOLDING       34.11      STPAP
# 1                   VALUE CONSULTING       28.75      STPAP
# 2       PUBLIC SUR LA PLACE DE TUNIS       27.58      STPAP
# 3                             HAN TN        4.83      STPAP
# 4  SWICORP CONSEIL ET INVESTISSEMENT        4.73      STPAP
#
# ✅ Found 5 shareholders:
#     Shareholder  Percentage Quote_Code
# 0          STIR       34.03      STPIL
# 1  GROUPE DRISS       21.21      STPIL
# 2          ETAP       18.28      STPIL
# 3          SNDP        0.63      STPIL
# 4          STEG        0.63      STPIL
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                 ÉTAT TUNISIEN       37.50        MGR
# 1  PUBLIC SUR LA PLACE DE TUNIS       22.21        MGR
# 2       SOCIÉTÉ TRABELSI & FILS       19.52        MGR
# 3                       COOPMAG       13.22        MGR
# 4   OFFICE DE COMMERCE TUNISIEN        7.55        MGR
#
# ✅ Found 3 shareholders:
#                              Shareholder  Percentage Quote_Code
# 0  COMPAGNIE FINANCIÈRE D’INVESTISSEMENT       65.27      SOTUV
# 1           PUBLIC SUR LA PLACE DE TUNIS       26.47      SOTUV
# 2                         LLOYD TUNISIEN        8.26      SOTUV
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                          SFBT       80.23      SPDIT
# 1  PUBLIC SUR LA PLACE DE TUNIS       14.71      SPDIT
# 2                           WIP        5.06      SPDIT
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                 GROUPE KILANI        68.0        STA
# 1  PUBLIC SUR LA PLACE DE TUNIS        20.0        STA
# 2             FAMILLE MARZOUGUI        12.0        STA
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                 ÉTAT TUNISIEN       38.64       STAR
# 1                      GROUPAMA       35.00       STAR
# 2  PUBLIC SUR LA PLACE DE TUNIS       26.36       STAR
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                 ÉTAT TUNISIEN       71.54        STB
# 1  PUBLIC SUR LA PLACE DE TUNIS       22.77        STB
# 2                          CNSS        5.69        STB
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                GROUPE EL AREM       73.15       STEQ
# 1  PUBLIC SUR LA PLACE DE TUNIS       14.25       STEQ
# 2                    STE FLOWER       12.60       STEQ
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                AFRICA HOLDING       70.87       STIP
# 1  PUBLIC SUR LA PLACE DE TUNIS       29.13       STIP
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0             FAMILLE CHABCHOUB       75.33        TGH
# 1  PUBLIC SUR LA PLACE DE TUNIS       14.83        TGH
# 2              SOCIÉTÉ ESSEYAHA        9.84        TGH
#
# ✅ Found 2 shareholders:
#                              Shareholder  Percentage Quote_Code
# 0           PUBLIC SUR LA PLACE DE TUNIS       58.03      TLNET
# 1  MOHAMED FRIKHA & HIKMA PARTICIPATIONS       41.97      TLNET
#
# ✅ Found 6 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                           CFI       37.27        TPR
# 1  PUBLIC SUR LA PLACE DE TUNIS       18.54        TPR
# 2                  YAHYA BAYAHI       12.22        TPR
# 3                  TAIEB BAYAHI       11.72        TPR
# 4                  TAHER BAYAHI       11.60        TPR
# 5                LLOYD TUNISIEN        8.65        TPR
#
# ✅ Found 0 shareholders:
# Empty DataFrame
# Columns: [Quote_Code]
# Index: []
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       56.30       TINV
# 1               TUNISIE LEASING       36.51       TINV
# 2          MOHAMED ILYES HAIDER        7.19       TINV
#
# ✅ Found 6 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0  PUBLIC SUR LA PLACE DE TUNIS       38.96        TRE
# 1                    GROUPE BNA       18.98        TRE
# 2                         COMAR       16.39        TRE
# 3                          STAR       15.62        TRE
# 4                         CTAMA        5.05        TRE
# 5                 ÉTAT TUNISIEN        5.00        TRE
#
# ✅ Found 5 shareholders:
#      Shareholder  Percentage Quote_Code
# 0  ÉTAT TUNISIEN       64.86       TAIR
# 1     AIR FRANCE        5.58       TAIR
# 2           CNSS        3.99       TAIR
# 3          CNRPS        3.90       TAIR
# 4           CNAM        1.67       TAIR
#
# ✅ Found 0 shareholders:
# Empty DataFrame
# Columns: [Quote_Code]
# Index: []
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                   GROUPE AMEN       59.33        TLS
# 1  PUBLIC SUR LA PLACE DE TUNIS       17.02        TLS
# 2                GROUPE POULINA       10.76        TLS
# 3              HORCHANI FINANCE        8.69        TLS
# 4           AUTRES ACTIONNAIRES        4.20        TLS
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                          BIAT       98.39       TVAL
# 1  PUBLIC SUR LA PLACE DE TUNIS        1.61       TVAL
#
# ✅ Found 2 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0       LOUKIL INVESTMENT GROUP        66.7       UADH
# 1  PUBLIC SUR LA PLACE DE TUNIS        33.3       UADH
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0                  GROUPE CARTE       39.51       UBCI
# 1  PUBLIC SUR LA PLACE DE TUNIS       26.98       UBCI
# 2             GROUPE TAMARZISTE       12.95       UBCI
# 3            GROUPE BNP PARIBAS       11.09       UBCI
# 4                GROUPE SELLAMI        9.47       UBCI
#
# ✅ Found 5 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0              SOCIETE GENERALE       52.34        UIB
# 1  PUBLIC SUR LA PLACE DE TUNIS       19.85        UIB
# 2                  GROUPE SASSI       10.71        UIB
# 3                   HBG HOLDING       10.62        UIB
# 4                 HABIB BOUAZIZ        6.48        UIB
#
# ✅ Found 3 shareholders:
#                     Shareholder  Percentage Quote_Code
# 0             RIDHA CHARFEDDINE       70.02       UMED
# 1  PUBLIC SUR LA PLACE DE TUNIS       17.70       UMED
# 2                EKUITY CAPITAL       12.28       UMED
#
# ✅ Found 6 shareholders:
#                                       Shareholder  Percentage Quote_Code
# 0                           MOHAMED HEDI BEN AYED       39.96      WIFAK
# 1  ISLAMIC CORPORATION FOR THE DÉVELOPPEMENT- ICD       30.00      WIFAK
# 2                                FAMILLE HAMROUNI       13.01      WIFAK
# 3       CAISSE DE DÉPÔTS ET DE CONSIGNATIONS -CDC       10.00      WIFAK
# 4                                             STB        4.50      WIFAK
# 5                    PUBLIC SUR LA PLACE DE TUNIS        2.53      WIFAK

# %% [markdown]
# performance

# %%
from io import StringIO

performance = pd.DataFrame([])

for quote in latest_quotes_df['Quote_Code']:
    # FIX 1: Remove the space in URL!
    url = f'https://www.ilboursa.com/marches/societe/{quote}'
    
    try:
        response = requests.get(url, headers=headers, timeout=30)
        response.raise_for_status()  # Check for HTTP errors
        
        tables = pd.read_html(StringIO(response.text))
        
        # Skip if no tables found
        if len(tables) == 0:
            print(f"⚠️  No tables found for {quote}")
            continue
            
        df = tables[-1]
        
        # Skip if table is empty or doesn't have expected structure
        if df.empty or 'Unnamed: 0' not in df.columns:
            print(f"⚠️  Unexpected table structure for {quote}")
            continue
        
        # Clean up column name
        df = df.rename(columns={'Unnamed: 0': 'Item'})
        
        # Unpivot/melt
        df_melted = df.melt(
            id_vars=['Item'],
            var_name='Year',
            value_name='Value'
        )
        
        # Add quote_code
        df_melted['Quote_Code'] = quote
        
        # Reorder columns
        df_melted = df_melted[['Quote_Code', 'Year', 'Item', 'Value']]
        
        # FIX 2: Clean ONLY this batch, not entire performance dataframe
        df_melted['Value'] = (
            df_melted['Value']
            .astype(str)
            .str.replace(' ', '', regex=False)
            .str.replace(',', '.', regex=False)
            .str.replace('%', '', regex=False)
            .replace(['-', 'nan', 'None', ''], pd.NA)
        )
        df_melted['Value'] = pd.to_numeric(df_melted['Value'], errors='coerce')
        
        # Append
        performance = pd.concat([performance, df_melted], ignore_index=True)
        
        print(f"✅ Processed {quote}: {len(df_melted)} rows")
        
    except Exception as e:
        print(f"❌ Error with {quote}: {e}")
        continue
performance["Publication_Date"] = pd.to_datetime('today').strftime('%Y-%m-%d')
# Loading existing performance.csv if it exists
try:
    existing_performance = pd.read_csv('performance.csv')
    performance = pd.concat([existing_performance, performance], ignore_index=True)
    performance.drop_duplicates(keep='last', inplace=True)
except FileNotFoundError:
    pass
# Saving to performance.csv
performance.to_csv('performance.csv', index=False)
# Out:
# ✅ Processed ADWYA: 35 rows
# ✅ Processed AETEC: 35 rows
# ✅ Processed AL: 35 rows
# ✅ Processed AB: 35 rows
# ✅ Processed AMS: 35 rows
# ✅ Processed ATB: 35 rows
# ✅ Processed ATL: 35 rows
# ✅ Processed ARTES: 35 rows
# ✅ Processed ASSAD: 35 rows
# ✅ Processed ASSMA: 35 rows
# ✅ Processed AST: 35 rows
# ✅ Processed TJARI: 35 rows
# ✅ Processed TJL: 35 rows
# ✅ Processed BT: 35 rows
# ✅ Processed BNA: 35 rows
# ✅ Processed BL: 35 rows
# ✅ Processed BHASS: 35 rows
# ✅ Processed BH: 35 rows
# ✅ Processed BHL: 35 rows
# ✅ Processed BIAT: 35 rows
# ✅ Processed BTE: 35 rows
# ✅ Processed CC: 35 rows
# ✅ Processed CELL: 35 rows
# ✅ Processed CREAL: 35 rows
# ✅ Processed CIL: 35 rows
# ✅ Processed SCB: 35 rows
# ✅ Processed CITY: 35 rows
# ✅ Processed DH: 35 rows
# ✅ Processed LSTR: 35 rows
# ✅ Processed NAKL: 35 rows
# ✅ Processed SOKNA: 35 rows
# ✅ Processed ECYCL: 35 rows
# ✅ Processed GIF: 35 rows
# ✅ Processed HL: 35 rows
# ✅ Processed XABYT: 35 rows
# ✅ Processed ICF: 35 rows
# ✅ Processed LNDOR: 35 rows
# ✅ Processed MAG: 35 rows
# ✅ Processed AMV: 35 rows
# ✅ Processed SAM: 35 rows
# ✅ Processed MIP: 35 rows
# ✅ Processed MNP: 35 rows
# ✅ Processed MPBS: 35 rows
# ✅ Processed NBL: 35 rows
# ✅ Processed PLAST: 35 rows
# ✅ Processed OTH: 35 rows
# ✅ Processed PGH: 35 rows
# ✅ Processed SAH: 35 rows
# ✅ Processed SMD: 35 rows
# ✅ Processed SERVI: 35 rows
# ✅ Processed SFBT: 35 rows
# ✅ Processed SIAME: 35 rows
# ✅ Processed SIMPA: 35 rows
# ✅ Processed SIPHA: 35 rows
# ✅ Processed SITS: 35 rows
# ✅ Processed SMART: 35 rows
# ✅ Processed ALKIM: 35 rows
# ✅ Processed SOMOC: 35 rows
# ✅ Processed SOPAT: 35 rows
# ✅ Processed SOTEM: 35 rows
# ✅ Processed SOTET: 35 rows
# ✅ Processed STPAP: 35 rows
# ✅ Processed STPIL: 35 rows
# ✅ Processed MGR: 35 rows
# ✅ Processed SOTUV: 35 rows
# ✅ Processed SPDIT: 35 rows
# ✅ Processed STA: 35 rows
# ✅ Processed STAR: 35 rows
# ✅ Processed STB: 35 rows
# ✅ Processed STEQ: 35 rows
# ✅ Processed STIP: 35 rows
# ✅ Processed TGH: 35 rows
# ✅ Processed TLNET: 35 rows
# ✅ Processed TPR: 35 rows
# ✅ Processed PX1: 7 rows
# ✅ Processed TINV: 35 rows
# ✅ Processed TRE: 35 rows
# ✅ Processed TAIR: 35 rows
# ✅ Processed TBIDX: 7 rows
# ✅ Processed TLS: 35 rows
# ✅ Processed TVAL: 28 rows
# ✅ Processed UADH: 28 rows
# ✅ Processed UBCI: 35 rows
# ✅ Processed UIB: 35 rows
# ✅ Processed UMED: 35 rows
# ✅ Processed WIFAK: 35 rows
